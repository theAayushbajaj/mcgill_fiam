# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

import pickle

# %%
with open('../objects/market_caps.pkl', 'rb') as f:
    market_caps = pickle.load(f)
    
with open('../objects/prices.pkl', 'rb') as f:
    prices = pickle.load(f)
    
with open('../objects/signals.pkl', 'rb') as f:
    signals = pickle.load(f)

# %%
market_caps
# Out:
#                 CSCO.csv      TROW.csv      ISRG.csv       NVR.csv  \
# datetime
# 2000-01-31  350424.19338           NaN           NaN           NaN
# 2000-02-29  358193.22450           NaN           NaN           NaN
# 2000-03-31  432407.91656           NaN           NaN           NaN
# 2000-04-28  505804.81588           NaN           NaN           NaN
# 2000-05-31  485366.20313           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2023-08-31  211594.64372  27646.602179  113979.55986  20489.623370
# 2023-09-29  233185.09380  25172.628603  109861.67883  20815.605375
# 2023-10-31  217989.15927  23442.640414  102886.08301  19464.210563
# 2023-11-30  211074.37432  20224.035000   92320.32027  17666.792063
# 2023-12-29  196590.97322  22376.050486  109438.05919  19567.985245
#
#                 LECO.csv       DVN.csv       CR.csv        CE.csv  \
# datetime
# 2000-01-31    899.126250           NaN  1309.583625           NaN
# ...

# %%
prices
# Out:
#               CSCO.csv    TROW.csv     ISRG.csv      NVR.csv    LECO.csv  \
# datetime
# 2000-01-31  107.125000         NaN          NaN          NaN   20.625000
# 2000-02-29  109.500000         NaN          NaN          NaN   19.562500
# 2000-03-31  132.187500         NaN          NaN          NaN   19.500000
# 2000-04-28  154.624999         NaN          NaN          NaN   24.327500
# 2000-05-31  138.656250         NaN          NaN          NaN         NaN
# ...                ...         ...          ...          ...         ...
# 2023-08-31  149.635031  437.624079  1962.105663  4643.091208  190.833710
# 2023-09-29  164.903318  398.463013  1891.218234  4695.283787  182.989666
# 2023-10-31  154.580685  376.663466  1767.891161  4390.455638  173.453198
# 2023-11-30  151.015216  325.050470  1586.015285  3985.019930  166.783765
# 2023-12-29  140.151855  359.638705  1880.089168  4531.881400  188.977068
#
#                DVN.csv     CR.csv      CE.csv     MRO.csv      BA.csv  ...  \
# ...

# %%
signals
# Out:
#             CSCO.csv  TROW.csv  ISRG.csv   NVR.csv  LECO.csv   DVN.csv  \
# datetime
# 2000-01-31 -0.068428       NaN       NaN       NaN  0.839106       NaN
# 2000-02-29 -0.783230       NaN       NaN       NaN -0.297985       NaN
# 2000-03-31  0.536081       NaN       NaN       NaN  0.390178       NaN
# 2000-04-28  0.670178       NaN       NaN       NaN  0.807436       NaN
# 2000-05-31 -0.676545       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-08-31  0.081064  0.023052 -0.243806  0.311559  0.326531 -0.758359
# 2023-09-29 -0.594895 -0.797499  0.366664  0.463580  0.130692 -0.757577
# 2023-10-31  0.582665  0.320963  0.358667  0.745151  0.305159  0.251416
# 2023-11-30  0.952046  0.443243 -0.785380 -0.846110 -0.782436  0.248976
# 2023-12-29  0.238754  0.229679 -0.873826 -0.174776  0.843194 -0.978376
#
#               CR.csv    CE.csv   MRO.csv    BA.csv  ...   CRM.csv   PGR.csv  \
# ...
