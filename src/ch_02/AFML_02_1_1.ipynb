# %%
import sys

# add docs/references/De_Prado/AFML/research.py to path
sys.path.append('../../../../src/utils')
import afml_research as ars

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = ars.create_price_data()
